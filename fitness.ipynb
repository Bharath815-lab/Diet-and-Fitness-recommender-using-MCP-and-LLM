# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\KAMALA VASHINI B\fitness calorie chaitanya\fitness calorie\exercise.csv")

# %%
df
# Out:
#         User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp
# 0      14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1      14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2      11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3      16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4      17771927  female   27   154.0    58.0      10.0        81.0       39.8
# ...         ...     ...  ...     ...     ...       ...         ...        ...
# 14995  15644082  female   20   193.0    86.0      11.0        92.0       40.4
# 14996  17212577  female   27   165.0    65.0       6.0        85.0       39.2
# 14997  17271188  female   43   159.0    58.0      16.0        90.0       40.1
# 14998  18643037    male   78   193.0    97.0       2.0        84.0       38.3
# 14999  11751526    male   63   173.0    79.0      18.0        92.0       40.5
#
# [15000 rows x 8 columns]

# %%
df2=pd.read_csv(r"C:\Users\KAMALA VASHINI B\fitness calorie chaitanya\fitness calorie\calories.csv")

# %%
df = pd.concat([df,df2["Calories"]],axis=1)

# %%
df
# Out:
#         User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0      14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1      14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2      11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3      16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4      17771927  female   27   154.0    58.0      10.0        81.0       39.8
# ...         ...     ...  ...     ...     ...       ...         ...        ...
# 14995  15644082  female   20   193.0    86.0      11.0        92.0       40.4
# 14996  17212577  female   27   165.0    65.0       6.0        85.0       39.2
# 14997  17271188  female   43   159.0    58.0      16.0        90.0       40.1
# 14998  18643037    male   78   193.0    97.0       2.0        84.0       38.3
# 14999  11751526    male   63   173.0    79.0      18.0        92.0       40.5
#
#        Calories
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   User_ID     15000 non-null  int64
#  1   Gender      15000 non-null  str
#  2   Age         15000 non-null  int64
#  3   Height      15000 non-null  float64
#  4   Weight      15000 non-null  float64
#  5   Duration    15000 non-null  float64
#  6   Heart_Rate  15000 non-null  float64
#  7   Body_Temp   15000 non-null  float64
#  8   Calories    15000 non-null  float64
# dtypes: float64(6), int64(2), str(1)
# memory usage: 1.0 MB

# %%
df.describe()
# Out:
#             User_ID           Age        Height        Weight      Duration  \
# count  1.500000e+04  15000.000000  15000.000000  15000.000000  15000.000000
# mean   1.497736e+07     42.789800    174.465133     74.966867     15.530600
# std    2.872851e+06     16.980264     14.258114     15.035657      8.319203
# min    1.000116e+07     20.000000    123.000000     36.000000      1.000000
# 25%    1.247419e+07     28.000000    164.000000     63.000000      8.000000
# 50%    1.499728e+07     39.000000    175.000000     74.000000     16.000000
# 75%    1.744928e+07     56.000000    185.000000     87.000000     23.000000
# max    1.999965e+07     79.000000    222.000000    132.000000     30.000000
#
#          Heart_Rate     Body_Temp      Calories
# count  15000.000000  15000.000000  15000.000000
# mean      95.518533     40.025453     89.539533
# std        9.583328      0.779230     62.456978
# min       67.000000     37.100000      1.000000
# ...

# %%
df.isnull().sum()
# Out:
# User_ID       0
# Gender        0
# Age           0
# Height        0
# Weight        0
# Duration      0
# Heart_Rate    0
# Body_Temp     0
# Calories      0
# dtype: int64

# %%
df.drop(columns = ["User_ID"],inplace =True)

# %%
Num_col = [col for col in df.columns if df[col].dtype != "O"]
Num_col
# Out:
# ['Gender',
#  'Age',
#  'Height',
#  'Weight',
#  'Duration',
#  'Heart_Rate',
#  'Body_Temp',
#  'Calories']

# %%
Numerical = df[Num_col]
Numerical.head()
# Out:
#    Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Calories
# 0    male   68   190.0    94.0      29.0       105.0       40.8     231.0
# 1  female   20   166.0    60.0      14.0        94.0       40.3      66.0
# 2    male   69   179.0    79.0       5.0        88.0       38.7      26.0
# 3  female   34   179.0    71.0      13.0       100.0       40.5      71.0
# 4  female   27   154.0    58.0      10.0        81.0       39.8      35.0

# %%
# !pip install matplotlib seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df['Gender'] = df['Gender'].map({'male': 1, 'female': 0})
df.head()
# Out:
#    Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Calories
# 0       1   68   190.0    94.0      29.0       105.0       40.8     231.0
# 1       0   20   166.0    60.0      14.0        94.0       40.3      66.0
# 2       1   69   179.0    79.0       5.0        88.0       38.7      26.0
# 3       0   34   179.0    71.0      13.0       100.0       40.5      71.0
# 4       0   27   154.0    58.0      10.0        81.0       39.8      35.0

# %%
X = df.drop(columns = ["Calories"])
y = df["Calories"]

# %%
# Split the Data
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state=1)

# %%
#from sklearn import metrics
import joblib

def predict(ml_model):
    model=ml_model.fit(X_train,y_train)
    print('Score : {}'.format(model.score(X_train,y_train)))
    y_prediction=model.predict(X_test)
    print('predictions are: \n {}'.format(y_prediction))
    print('\n')

    r2_score=metrics.r2_score(y_test,y_prediction)
    print('r2 score: {}'.format(r2_score))

    print('MAE:',metrics.mean_absolute_error(y_test,y_prediction))
    print('MSE:',metrics.mean_squared_error(y_test,y_prediction))
    print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test,y_prediction)))
    model_path="random_forest_regressor.joblib"
    joblib.dump(model, model_path)
    print(f"Model saved at {model_path}")
    #sns.distplot(y_test-y_prediction)

# %%
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: C:\Program Files\Python311\python.exe -m pip install --upgrade pip

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
import numpy as np
regression = predict(RandomForestRegressor())
regression
# Out:
# Score : 0.9996827853525263
# predictions are:
#  [196.81  67.05 196.87 ...  27.5  110.73  14.3 ]
#
#
# r2 score: 0.9976812407844984
# MAE: 1.8147566666666668
# MSE: 9.3097475
# RMSE: 3.0511878834316315
# Model saved at random_forest_regressor.joblib

# %%
import numpy as np
import joblib
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from sklearn import metrics

def predict_ann():
    
    # Build ANN model
    model = Sequential()
    
    # Input layer + Hidden layer 1
    model.add(Dense(64, activation='relu', input_dim=X_train.shape[1]))
    
    # Hidden layer 2
    model.add(Dense(32, activation='relu'))
    
    # Output layer (1 neuron for regression)
    model.add(Dense(1))

    # Compile model
    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='mse',
                  metrics=['mae'])

    # Train model
    model.fit(X_train, y_train,
              epochs=100,
              batch_size=32,
              verbose=1)

    # Predictions
    y_prediction = model.predict(X_test)

    print("R2 Score:", metrics.r2_score(y_test, y_prediction))
    print("MAE:", metrics.mean_absolute_error(y_test, y_prediction))
    print("MSE:", metrics.mean_squared_error(y_test, y_prediction))
    print("RMSE:", np.sqrt(metrics.mean_squared_error(y_test, y_prediction)))

    # Save model
    model.save("ann_model.h5")
    print("Model saved as ann_model.h5")

    return model


ann_model = predict_ann()
# Out:
# Epoch 1/100
# C:\Users\KAMALA VASHINI B\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2749.1836 - mae: 40.0248
# Epoch 2/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 234.8346 - mae: 10.8020
# Epoch 3/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 105.8300 - mae: 7.5553
# Epoch 4/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 92.3238 - mae: 7.1980
# Epoch 5/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 85.0128 - mae: 6.9282
# Epoch 6/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 78.0365 - mae: 6.5937
# Epoch 7/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 69.1504 - mae: 6.1732
# Epoch 8/100
# ...

# %%
from joblib import load

# Load the saved model
model = load('random_forest_regressor.joblib')
n=10
# Ensure you retrieve the first row properly
print(X_test.iloc[[n]])
# Using .iloc for the first row (as a DataFrame)
y_prediction = model.predict(X_test.iloc[[n]])

print(f"Prediction for calories burnt: {y_prediction}")
print(f"Actual calories burnt: {y_test.iloc[n]}")
# Out:
#       Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp
# 6331       0   34   147.0    52.0      19.0        92.0       40.4
# Prediction for calories burnt: [91.89]
# Actual calories burnt: 92.0

# %%
pip install gradio
# Out:
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\KAMALA VASHINI B\fitness calorie chaitanya\fitness calorie\.venv\Scripts\python.exe: No module named pip

# %%
import gradio as gr
from joblib import load
import pandas as pd

# Load the saved model
model = load('random_forest_regressor.joblib')

# Define the prediction function
def predict_calories(Gender, Age, Height, Weight, Duration, Heart_Rate, Body_Temp):
    # Create a DataFrame with the input values
    input_data = pd.DataFrame([[Gender, Age, Height, Weight, Duration, Heart_Rate, Body_Temp]],
                              columns=['Gender', 'Age', 'Height', 'Weight', 'Duration', 'Heart_Rate', 'Body_Temp'])
    
    # Make a prediction using the model
    prediction = model.predict(input_data)
    
    return f"Predicted Calories Burnt: {prediction[0]:.2f}"

# Define the Gradio interface with a submit button
interface = gr.Interface(
    fn=predict_calories,
    inputs=[
        gr.Slider(minimum=0, maximum=1, step=1, label="Gender (0 = Female, 1 = Male)"),
        gr.Number(label="Age"),
        gr.Number(label="Height (in cm)"),
        gr.Number(label="Weight (in kg)"),
        gr.Number(label="Duration (in minutes)"),
        gr.Number(label="Heart Rate (beats per minute)"),
        gr.Number(label="Body Temperature (°C)")
    ],
    outputs="text",
    live=False,  # Disable live updates so the prediction only occurs after pressing Submit
    allow_flagging="never"  # Optionally disable flagging
)

# Add a submit button (it will be added automatically since live=False)
interface.launch(share=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 import gradio as gr
#       2 from joblib import load
#       3 import pandas as pd
#
# ModuleNotFoundError: No module named 'gradio'

# %%
df_3=pd.read_csv(r"D:\fitness calorie\nutrition.csv")

# %%
df_3

# %%
df_cleaned = df_3.replace(to_replace=r'(\d+\.?\d*)\s*(mg|mcg|g)', value=r'\1', regex=True)

# %%
df_cleaned

# %%
df_cleaned.info()

# %%
df_filled = df_cleaned.fillna(0)

# %%
df_filled

# %%
for column in df_filled.columns:
    if column != "name":  # Skip the 'name' column
        df_filled[column] = pd.to_numeric(df_filled[column], errors='coerce')

# %%
df_filled

# %%
df=df_filled

# %%
# Save the updated DataFrame to a CSV file
df_filled.to_csv(r'D:\fitness calorie\nutrition_updated.csv', index=False)  # Replace with your desired file path

# %%
pip install pulp

# %%
import pandas as pd
from pulp import LpMaximize, LpProblem, LpVariable, lpSum

# Replace 'df' with your DataFrame
threshold = 500  # Example calorie threshold

# Ensure the DataFrame has required columns
if 'protein' not in df.columns or 'calories' not in df.columns:
    print("Ensure the dataset contains 'protein' and 'calories' columns.")
else:
    # Prepare data
    df['calories'] = pd.to_numeric(df['calories'], errors='coerce').fillna(0)
    df['protein'] = pd.to_numeric(df['protein'], errors='coerce').fillna(0)
    
    # Create LP problem
    problem = LpProblem("Maximize_Protein", LpMaximize)
    
    # Define variables
    choices = [LpVariable(f"choice_{i}", cat="Binary") for i in range(len(df))]
    
    # Objective: Maximize protein
    problem += lpSum(choices[i] * df.iloc[i]['protein'] for i in range(len(df)))
    
    # Constraints
    problem += lpSum(choices[i] * df.iloc[i]['calories'] for i in range(len(df))) <= threshold  # Calorie threshold
    problem += lpSum(choices) == 3  # Select exactly 3 items
    
    # Solve problem
    problem.solve()
    
    # Retrieve selected foods
    selected_items = [i for i in range(len(choices)) if choices[i].varValue == 1]
    if selected_items:
        selected_foods = df.iloc[selected_items]
        print("Selected Foods:")
        print(selected_foods[['name', 'calories', 'protein']])
        print(f"Total Calories: {selected_foods['calories'].sum()}, Total Protein: {selected_foods['protein'].sum()}")
    else:
        print("No solution found within the calorie threshold.")

# %%
import pandas as pd
from pulp import LpMaximize, LpProblem, LpVariable, lpSum, LpStatus

# Replace 'df' with your DataFrame
threshold = 500  # Example calorie threshold

# Ensure the DataFrame has required columns
if 'protein' not in df.columns or 'calories' not in df.columns:
    print("Ensure the dataset contains 'protein' and 'calories' columns.")
else:
    # Prepare data
    df['calories'] = pd.to_numeric(df['calories'], errors='coerce').fillna(0)
    df['protein'] = pd.to_numeric(df['protein'], errors='coerce').fillna(0)

    # Store multiple solutions
    solutions = []

    # Run optimization iteratively
    for _ in range(3):  # Generate at least 3 sets of recommendations
        # Create LP problem
        problem = LpProblem("Maximize_Protein", LpMaximize)

        # Define variables
        choices = [LpVariable(f"choice_{i}", cat="Binary") for i in range(len(df))]

        # Objective: Maximize protein
        problem += lpSum(choices[i] * df.iloc[i]['protein'] for i in range(len(df)))

        # Constraints
        problem += lpSum(choices[i] * df.iloc[i]['calories'] for i in range(len(df))) <= threshold  # Calorie threshold
        problem += lpSum(choices) == 3  # Select exactly 3 items

        # Exclude previous solutions
        for solution in solutions:
            problem += lpSum(choices[i] for i in solution) <= 2  # Exclude identical solutions

        # Solve problem
        status = problem.solve()
        if LpStatus[status] != "Optimal":
            print("No more feasible solutions found.")
            break

        # Retrieve selected items
        selected_items = [i for i in range(len(choices)) if choices[i].varValue == 1]
        solutions.append(selected_items)

        # Display results
        selected_foods = df.iloc[selected_items]
        print(f"Recommendation Set {len(solutions)}:")
        print(selected_foods[['name', 'calories', 'protein']])
        print(f"Total Calories: {selected_foods['calories'].sum()}, Total Protein: {selected_foods['protein'].sum()}\n")

    if not solutions:
        print("No feasible solutions found.")

# %%
import pandas as pd
from pulp import LpMaximize, LpProblem, LpVariable, lpSum, LpStatus

# Replace 'df' with your DataFrame
threshold = 196  # Example calorie threshold

# Ensure the DataFrame has required columns
if 'protein' not in df.columns or 'calories' not in df.columns:
    print("Ensure the dataset contains 'protein' and 'calories' columns.")
else:
    # Prepare data
    df['calories'] = pd.to_numeric(df['calories'], errors='coerce').fillna(0)
    df['protein'] = pd.to_numeric(df['protein'], errors='coerce').fillna(0)

    # Store multiple solutions and excluded items
    solutions = []
    excluded_items = set()

    # Run optimization iteratively to get 3 distinct sets
    for _ in range(3):  # Generate at least 3 sets of recommendations
        # Create LP problem
        problem = LpProblem("Maximize_Protein", LpMaximize)

        # Define variables
        choices = [LpVariable(f"choice_{i}", cat="Binary") for i in range(len(df))]

        # Objective: Maximize protein
        problem += lpSum(choices[i] * df.iloc[i]['protein'] for i in range(len(df)))

        # Constraints
        problem += lpSum(choices[i] * df.iloc[i]['calories'] for i in range(len(df))) <= threshold  # Calorie threshold
        problem += lpSum(choices) == 3  # Select exactly 3 items

        # Exclude previously selected items
        for i in excluded_items:
            problem += choices[i] == 0  # Exclude already selected items

        # Solve problem
        status = problem.solve()
        if LpStatus[status] != "Optimal":
            print("No more feasible solutions found.")
            break

        # Retrieve selected items
        selected_items = [i for i in range(len(choices)) if choices[i].varValue == 1]

        # Store selected items to exclude in future recommendations
        excluded_items.update(selected_items)

        # Append solution
        solutions.append(selected_items)

        # Display results
        selected_foods = df.iloc[selected_items]
        print(f"Recommendation Set {len(solutions)}:")
        print(selected_foods[['name', 'calories', 'protein']])
        print(f"Total Calories: {selected_foods['calories'].sum()}, Total Protein: {selected_foods['protein'].sum()}\n")

    if not solutions:
        print("No feasible solutions found.")

# %%
import pandas as pd
import gradio as gr
from pulp import LpMaximize, LpProblem, LpVariable, lpSum, LpStatus
from joblib import load

# Load the saved model (you need to ensure the model is saved properly)
model = load('random_forest_regressor.joblib')

# Define the prediction function for calories burnt
def predict_calories(Gender, Age, Height, Weight, Duration, Heart_Rate, Body_Temp):
    # Create a DataFrame with the input values
    input_data = pd.DataFrame([[Gender, Age, Height, Weight, Duration, Heart_Rate, Body_Temp]],
                              columns=['Gender', 'Age', 'Height', 'Weight', 'Duration', 'Heart_Rate', 'Body_Temp'])
    
    # Make a prediction using the model
    prediction = model.predict(input_data)
    
    return prediction[0]  # Return predicted calories burnt

# Define the optimization function to recommend foods based on predicted calories burnt
def recommend_foods(Gender, Age, Height, Weight, Duration, Heart_Rate, Body_Temp):
    # Get the predicted calories burnt from the prediction function
    predicted_calories = predict_calories(Gender, Age, Height, Weight, Duration, Heart_Rate, Body_Temp)
    
    threshold = predicted_calories  # Set the calorie threshold to the predicted value
    print(f"Predicted Calories Burnt: {predicted_calories}")

    # Prepare data
    df['calories'] = pd.to_numeric(df['calories'], errors='coerce').fillna(0)
    df['protein'] = pd.to_numeric(df['protein'], errors='coerce').fillna(0)

    # Store multiple solutions and excluded items
    solutions = []
    excluded_items = set()

    # Run optimization iteratively to get 3 distinct sets
    for _ in range(3):  # Generate at least 3 sets of recommendations
        # Create LP problem
        problem = LpProblem("Maximize_Protein", LpMaximize)

        # Define variables
        choices = [LpVariable(f"choice_{i}", cat="Binary") for i in range(len(df))]

        # Objective: Maximize protein
        problem += lpSum(choices[i] * df.iloc[i]['protein'] for i in range(len(df)))

        # Constraints
        problem += lpSum(choices[i] * df.iloc[i]['calories'] for i in range(len(df))) <= threshold  # Calorie threshold
        problem += lpSum(choices) == 3  # Select exactly 3 items

        # Exclude previously selected items
        for i in excluded_items:
            problem += choices[i] == 0  # Exclude already selected items

        # Solve problem
        status = problem.solve()
        if LpStatus[status] != "Optimal":
            print("No more feasible solutions found.")
            break

        # Retrieve selected items
        selected_items = [i for i in range(len(choices)) if choices[i].varValue == 1]

        # Store selected items to exclude in future recommendations
        excluded_items.update(selected_items)

        # Append solution
        solutions.append(selected_items)

        # Display results
        selected_foods = df.iloc[selected_items]
        print(f"Recommendation Set {len(solutions)}:")
        print(selected_foods[['name', 'calories', 'protein']])
        print(f"Total Calories: {selected_foods['calories'].sum()}, Total Protein: {selected_foods['protein'].sum()}\n")

    if not solutions:
        return "No feasible solutions found."
    
    # Prepare the output format to return the recommendations
    output = ""
    for idx, solution in enumerate(solutions):
        selected_foods = df.iloc[solution]
        output += f"Recommendation Set {idx+1}:\n"
        output += selected_foods[['name', 'calories', 'protein']].to_string(index=False)
        output += f"\nTotal Calories: {selected_foods['calories'].sum()}, Total Protein: {selected_foods['protein'].sum()}\n\n"
    
    return output

# Define the Gradio interface
interface = gr.Interface(
    fn=recommend_foods,
    inputs=[
        gr.Slider(minimum=0, maximum=1, step=1, label="Gender (0 = Female, 1 = Male)"),
        gr.Number(label="Age"),
        gr.Number(label="Height (in cm)"),
        gr.Number(label="Weight (in kg)"),
        gr.Number(label="Duration (in minutes)"),
        gr.Number(label="Heart Rate (beats per minute)"),
        gr.Number(label="Body Temperature (°C)")
    ],
    outputs="text",
    live=False,  # Disable live updates so the prediction only occurs after pressing Submit
    allow_flagging="never"  # Optionally disable flagging
)

# Launch the app
interface.launch(share=True)
